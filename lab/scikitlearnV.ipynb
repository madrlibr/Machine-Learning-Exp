# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
dfLinear = pd.read_csv('../data/linear.csv')
dfLogistic = pd.read_csv('../data/logistic.csv')

x1 = dfLinear[['ps']]
y1 = dfLinear['fs']

x2 = dfLogistic[['value']]
y2 = dfLogistic['status']

print(dfLinear)
print(f"\n{dfLogistic}")
# Out:
#     ps  fs
# 0   90  93
# 1   87  88
# 2  100  98
# 3   78  78
# 4   75  76
# 5   74  76
# 6   70  69
# 7   50  60
# 8   20  10
#
#    value  status
# 0     90       1
# 1     87       1
# 2    100       1
# 3     78       1
# 4     75       1
# 5     74       0
# 6     70       0
# 7     50       0
# 8     20       0

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x1, y1, test_size=0.2, random_state=42)

modelLin = LinearRegression()
modelLin.fit(x_train.values, y_train)
y_pred = modelLin.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}, RMSE: {rmse}, R2: {r2}")
# Out:
# MAE: 7.0388966945204565, RMSE: 9.953666577577446, R2: 0.4945128656245802
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
input = np.array([10, 20, 30, 40, 50, 60, 70, 75, 80, 90, 100]).reshape(-1, 1)
for n in input:
    n = n.reshape(1, -1)
    ypred = int(model.predict(n).item())
    print(f"yPred {n}:\n{ypred}")
# Out:
# yPred [[10]]:
# 0
# yPred [[20]]:
# 11
# yPred [[30]]:
# 23
# yPred [[40]]:
# 34
# yPred [[50]]:
# 45
# yPred [[60]]:
# 57
# yPred [[70]]:
# 68
# yPred [[75]]:
# 74
# yPred [[80]]:
# 80
# yPred [[90]]:
# 91
# yPred [[100]]:
# 102

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x2, y2, test_size=0.2, random_state=42)

modelLog = LogisticRegression()
modelLog.fit(x_train.values, y_train)
y_pred = modelLog.predict(x_test)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
for n in input:
    n = n.reshape(1, -1)
    ypred = round(np.median(modelLog.predict(n)), 3)
    np.set_printoptions(suppress=True, precision=8)
    print(f"yPred {n}:\n{ypred}")
# Out:
# yPred [[10]]:
# 0.0
# yPred [[20]]:
# 0.0
# yPred [[30]]:
# 0.0
# yPred [[40]]:
# 0.0
# yPred [[50]]:
# 0.0
# yPred [[60]]:
# 0.0
# yPred [[70]]:
# 0.0
# yPred [[75]]:
# 1.0
# yPred [[80]]:
# 1.0
# yPred [[90]]:
# 1.0
# yPred [[100]]:
# 1.0
